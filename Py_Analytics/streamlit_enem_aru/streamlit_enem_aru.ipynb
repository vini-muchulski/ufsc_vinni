# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#https://colab.research.google.com/drive/1ihwqb-LiGYA3x5U_ABp_Rb-CfVdxbJ4X#scrollTo=c_rpWV5WZUxB

# %%
df_aru = pd.read_csv("enem_ararangua_2019.csv")

# %%
df_aru.head()
# Out:
#        ID   NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 0  679688   190001684332    2019                  4201406
# 1  679887   190001684531    2019                  4201406
# 2  679895   190001684539    2019                  4201406
# 3  679987   190001684631    2019                  4201406
# 4  680012   190001684656    2019                  4201406
#
#   NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 0               Araranguá                42               SC        18
# 1               Araranguá                42               SC        22
# 2               Araranguá                42               SC        18
# 3               Araranguá                42               SC        29
# 4               Araranguá                42               SC        17
#
#   TP_SEXO  TP_ESTADO_CIVIL  ...  Q017  Q018  Q019 Q020  Q021 Q022  Q023  Q024  \
# 0       F                1  ...     A     B     C    B     A    D     B     B
# 1       M                1  ...     A     B     B    B     A    E     A     B
# 2       F                1  ...     A     A     A    A     A    C     A     A
# 3       M                0  ...     A     B     B    B     A    D     A     B
# 4       M                1  ...     A     A     B    A     B    D     A     C
#
#    Q025   TESTS_GRADE
# 0     B        388.82
# 1     B        392.00
# 2     B        409.10
# 3     B        424.52
# 4     B        430.78
#
# [5 rows x 138 columns]

# %%
df_aru.shape
# Out:
# (1068, 138)

# %%
#grafico da distribuição das idades na prova enem 2019 - ararangua

sns.countplot(x="NU_IDADE", data=df_aru, width=0.3)  # Ajuste o valor de 'width' para controlar a largura da barra
plt.xticks(rotation=60, ha="right")
plt.xlabel("Idade")
plt.ylabel("Quantidade")
plt.tight_layout()
plt.show()

# %%
#grafico da distribuição dos generos na prova enem 2019 - ararangua

palette = sns.color_palette("husl", len(df_aru["TP_SEXO"].unique()))
sns.countplot(x="TP_SEXO", data=df_aru, width=0.3, palette=palette)
plt.xticks( ha="right")
plt.xlabel("Genero")
plt.ylabel("Quantidade")
plt.tight_layout()
plt.show()

# %%
#media das notas sem considerar redacao
df_aru["TESTS_GRADE"] = (df_aru["NU_NOTA_CN"] + df_aru["NU_NOTA_CH"] + df_aru["NU_NOTA_LC"] + df_aru["NU_NOTA_MT"])/5
df_aru["TESTS_GRADE"].head()
# Out:
# 0    388.82
# 1    392.00
# 2    409.10
# 3    424.52
# 4    430.78
# Name: TESTS_GRADE, dtype: float64

# %%
df_aru["TESTS_GRADE"].max()
# Out:
# 587.1

# %%
# histograma com a distribuiçao das notas na cidade de ararangua
sns.histplot(data=df_aru, x="TESTS_GRADE", kde=True)
plt.xlabel("Distribuição das notas")
plt.ylabel("Quantidade")
plt.tight_layout()
plt.show()
